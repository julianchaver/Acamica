# %% [markdown]
# # Ensambles - Boosting
#
# A lo largo del notebook vamos a trabajar con el siguiente dataset, que es el que utilizamos en los encuentros anteriores:
#
# https://www.kaggle.com/jsphyg/weather-dataset-rattle-package
#
# Si ya te sientes seguro/a, puedes utilizar un clasificador AdaBoost de Scikit-Learn sobre este dataset sin seguir los pasos que te dejamos más abajo. También, puedes seguirlos, pero borrando las pistas que te dejamos. ¡Anímate a probar más cosas solo/a!
#
# ### Carga de datos
#
# Volvemos a cargas las librerías, importar el dataset y limpiarlo.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

from sklearn.tree import DecisionTreeClassifier

import sklearn.metrics as metrics

from sklearn.model_selection import learning_curve

# %%
data = pd.read_csv("DS_Bitácora_27_Weather.csv")
# Columnas con muchos NaNs
columnas_descartables = ['Sunshine','Evaporation','Cloud3pm','Cloud9am','Location','Date']
data = data.drop(columns=columnas_descartables)
data = data.dropna()

# Columnas con variables categoricas
columnas_descartables = ['WindGustDir','WindDir9am','WindDir3pm','RainToday', 'RISK_MM']
data = data.drop(columns=columnas_descartables)

# Variables correlacionadas
data = data.drop(columns=['Temp3pm', 'Pressure9am'])

# Mapeo
data['RainTomorrow'] = data['RainTomorrow'].map({'Yes':1,'No':0})

# %% [markdown]
# ## 1. AdaBoost
#
# El objetivo de boosting es generar un modelo fuerte a partir de entrenar sucesivamente modelos débiles y combinar sus resultados. La idea es que cada modelo débil que agrego se enfoque en las instancias que fueron clasificadas erroneamente hasta el momento. Empecemos por decidir sobre que fetures del dataset vamos a trabajar (si trabajan sobre 2, luego podrán visualizar):

# %%
# Elegimos sobre que coolumnas queremos trabajar
columnas_entrenamiento = ['MaxTemp', 'Humidity3pm']
X = data[columnas_entrenamiento]
y = data.RainTomorrow

# Separamos los datos en train y test (held-out) - Utilice un 30% del dataset como test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify = y)

# %% [markdown]
# Recordemos que este tipo de ensamble se enfoca en mejorar el sesgo de los modelos individuales a partir de los cuales está construido, por lo cual se suele usar modelos de alto sesgo y baja varianza.
#
# 1. Empiece por importar el clasificador AdaBoostClassifier y el modelo que usaremos como estimador debil, el DecisionTreeClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# 2. Defina el modelo de manera que utilice 250 árboles de profundidad dos (2). Luego probaremos que sucede para mayores profundidades.

# %%
ada_clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=10),algorithm='SAMME', n_estimators=250)
# Entrenamos el modelo
ada_clf.fit(X_test, y_test)
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#                    base_estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                          class_weight=None,
#                                                          criterion='gini',
#                                                          max_depth=10,
#                                                          max_features=None,
#                                                          max_leaf_nodes=None,
#                                                          min_impurity_decrease=0.0,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=2,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          presort='deprecated',
#                                                          random_state=None,
#                                                          splitter='best'),
#                    learning_rate=1.0, n_estimators=250, random_state=None)

# %% [markdown]
# 3. Calcule el error sobre el training set y sobre el test set. En base a estos resultados, ¿les parece que este ensamble está inclinado hacia el sesgo o hacia la varianza?

# %%
y_train_pred = ada_clf.predict(X_train)
y_test_pred = ada_clf.predict(X_test)
print('Accuracy sobre el test set: ',metrics.accuracy_score(y_train,y_train_pred))
print('Accuracy sobre el train set: ',metrics.accuracy_score(y_test,y_test_pred))
# Out:
# Accuracy sobre el test set:  0.7960299270265286
# Accuracy sobre el train set:  0.8848080646648431

# %% [markdown]
# 4. Veamos ahora cómo es la distribución de los pesos de cada árbol. Para esto vamos a graficar el número del árbol vs el peso que el algoritmo le está dando para la clasificación final. Además, graficaremos también el accuracy de cada arbol sobre el training set.

# %%
# Puede que el algoritmo termine antes de agregar todos los arboles
# Tomamos entonces la cantidad de arboles que realmente tiene el ensamble
numero_arboles = len(ada_clf)

# En la variable estimator_weights_ esta el peso de cada arbol
pesos = ada_clf.estimator_weights_[:numero_arboles]

# Calculamos el accuracy DE CADA ARBOL en el ensamble. En estimator_errors_ esta el error que comete cada uno.
errores_arboles = ada_clf.estimator_errors_[:numero_arboles]
# Como puede calcular el accuracy de cada arbol a partir de saber el error que comete cada uno?
accuracy_arboles = 1-errores_arboles

# Graficamos
plt.figure(figsize = (12,6))
plt.subplot(121)
# En el eje 'x' ponemos el índice (número) de cada arbol, en el 'y' los pesos
plt.plot(range(1, numero_arboles + 1), pesos)
plt.ylabel('Peso')
plt.xlabel('Número de árbol')
plt.ylim((0, pesos.max() * 1.1))
plt.xlim((-20, numero_arboles + 20))
plt.subplot(122)
# En el eje 'x' ponemos el índice (número) de cada arbol, en el 'y' el accuracy de cada arbol
plt.plot(range(1, numero_arboles + 1), accuracy_arboles)
plt.ylabel('Accuracy en trainin set')
plt.xlabel('Número de árbol')
# Out:
# Text(0.5, 0, 'Número de árbol')

# %% [markdown]
# 5. ¿Le parece relevante la contribución de todos los árboles?¿Cómo se relaciona el accuracy de cada árbol con el peso que le damos en la clasificación final?
#
# 6. Veamos cómo cambia el error en el training set y en el test set a medida que agregamos árboles. Para esto vamos a utilizar un metodo llamado `staged_predict`, que nos devuelve la predicción del ensamble en cada instancia en que fuimos agregandole un nuevo estimador.

# %%
# Definimos listas vacias donde vamos a "appendear" (agregar) los valores
accuracy_test = []
accuracy_train = []

# Calculamos el accuracy sobre el test set
for prediccion_test in ada_clf.staged_predict(X_test):
    accuracy_test.append(metrics.accuracy_score(prediccion_test,y_test))
    
# Calculamos el accuracy sobre el training set    
for prediccion_train in ada_clf.staged_predict(X_train):  
    accuracy_train.append(metrics.accuracy_score(prediccion_train,y_train))
    
plt.plot(range(1, len(accuracy_test) + 1), accuracy_test, label = 'Test')
plt.plot(range(1, len(accuracy_test) + 1), accuracy_train, label = 'Train')
plt.legend()
plt.ylabel('Accuracy en el test set')
plt.xlabel('Número de árboles')
# Out:
# Text(0.5, 0, 'Número de árboles')

# %% [markdown]
# 7. Grafiquemos la frontera de decisión del clasificador

# %%
N = 20 #para no graficar todos los puntos y saturar el grafico

plt.figure(figsize = (8,6))

ax = sns.scatterplot(X_test[::N].MaxTemp, X_test[::N].Humidity3pm, hue=y_test[::N], palette='Set2')
xlim = ax.get_xlim()
ylim = ax.get_ylim()
xx, yy = np.meshgrid(np.linspace(*xlim, num=200),
                      np.linspace(*ylim, num=200))
Z = ada_clf.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
contours = ax.contourf(xx, yy, Z, alpha=0.3, cmap = 'Set2')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 8. Repita lo realizado hasta ahora pero utilice árboles de profundidad diez. Preste atención a las curvas de accuracy en train y test y al gráfico de la frontera. ¿Qué le parece que esta sucediendo en este caso?
#
# ### 2. XGBoost
#
# Instalar y entrenar un modelo con `XGBoost` sobre este dataset. Explorar diferencias y similitudes con `Adaboost`.

# %%
import xgboost as xgb

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify = y)

# XGB Classifier
xg_cl = xgb.XGBClassifier(objective='binary:logistic', n_estimators=250, seed=0)
eval_set = [(X_train, y_train), (X_test, y_test)]

# Fit the classifier to the training set
xg_cl.fit(X_train, y_train, eval_metric=["error"], eval_set=eval_set, verbose=True)
results = xg_cl.evals_result()

# Predict the labels of the test set (cjto. prueba): preds
predictions = xg_cl.predict(X_test)

# Compute the accuracy: accuracy
accuracy = float(np.sum(predictions == y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy*100))

# plot classification error
epochs = len(results['validation_0']['error'])
x_axis = range(0, epochs)
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['error'], label='Train')
ax.plot(x_axis, results['validation_1']['error'], label='Test')
plt.legend()
plt.ylabel('Accuracy en el test set')
plt.xlabel('Número de árboles')
# Out:
# [0]	validation_0-error:0.172515	validation_1-error:0.170452
# [1]	validation_0-error:0.171975	validation_1-error:0.170544
# [2]	validation_0-error:0.171975	validation_1-error:0.170544
# [3]	validation_0-error:0.172515	validation_1-error:0.170452
# [4]	validation_0-error:0.172515	validation_1-error:0.170452
# [5]	validation_0-error:0.172515	validation_1-error:0.170452
# [6]	validation_0-error:0.171975	validation_1-error:0.170544
# [7]	validation_0-error:0.171975	validation_1-error:0.170544
# [8]	validation_0-error:0.172515	validation_1-error:0.170452
# [9]	validation_0-error:0.172515	validation_1-error:0.170452
# [10]	validation_0-error:0.171975	validation_1-error:0.170544
# [11]	validation_0-error:0.171975	validation_1-error:0.170544
# [12]	validation_0-error:0.171975	validation_1-error:0.170544
# [13]	validation_0-error:0.171975	validation_1-error:0.170544
# [14]	validation_0-error:0.171975	validation_1-error:0.170544
# [15]	validation_0-error:0.171975	validation_1-error:0.170544
# [16]	validation_0-error:0.171975	validation_1-error:0.170544
# [17]	validation_0-error:0.171975	validation_1-error:0.170544
# [18]	validation_0-error:0.171975	validation_1-error:0.170544
# [19]	validation_0-error:0.171975	validation_1-error:0.170544
# [20]	validation_0-error:0.171975	validation_1-error:0.170544
# [21]	validation_0-error:0.171975	validation_1-error:0.170544
# [22]	validation_0-error:0.171975	validation_1-error:0.170544
# [23]	validation_0-error:0.171975	validation_1-error:0.170544
# [24]	validation_0-error:0.171975	validation_1-error:0.170544
# [25]	validation_0-error:0.171777	validation_1-error:0.170514
# [26]	validation_0-error:0.171659	validation_1-error:0.170452
# [27]	validation_0-error:0.171659	validation_1-error:0.170452
# [28]	validation_0-error:0.171777	validation_1-error:0.170514
# [29]	validation_0-error:0.171659	validation_1-error:0.170452
# [30]	validation_0-error:0.171777	validation_1-error:0.170514
# [31]	validation_0-error:0.171777	validation_1-error:0.170514
# [32]	validation_0-error:0.171251	validation_1-error:0.169991
# [33]	validation_0-error:0.171369	validation_1-error:0.170114
# [34]	validation_0-error:0.171198	validation_1-error:0.170053
# [35]	validation_0-error:0.171198	validation_1-error:0.170053
# [36]	validation_0-error:0.171198	validation_1-error:0.170053
# [37]	validation_0-error:0.171079	validation_1-error:0.169991
# [38]	validation_0-error:0.171066	validation_1-error:0.169899
# [39]	validation_0-error:0.17104	validation_1-error:0.169745
# [40]	validation_0-error:0.170921	validation_1-error:0.169684
# [41]	validation_0-error:0.17104	validation_1-error:0.169745
# [42]	validation_0-error:0.17104	validation_1-error:0.169745
# [43]	validation_0-error:0.171106	validation_1-error:0.16953
# [44]	validation_0-error:0.171106	validation_1-error:0.16953
# [45]	validation_0-error:0.171119	validation_1-error:0.169561
# [46]	validation_0-error:0.171119	validation_1-error:0.169561
# [47]	validation_0-error:0.171053	validation_1-error:0.169592
# [48]	validation_0-error:0.171053	validation_1-error:0.169592
# [49]	validation_0-error:0.170934	validation_1-error:0.16953
# [50]	validation_0-error:0.171013	validation_1-error:0.169653
# [51]	validation_0-error:0.171053	validation_1-error:0.16953
# [52]	validation_0-error:0.171066	validation_1-error:0.169592
# [53]	validation_0-error:0.171053	validation_1-error:0.16953
# [54]	validation_0-error:0.171	validation_1-error:0.169376
# [55]	validation_0-error:0.170974	validation_1-error:0.169346
# [56]	validation_0-error:0.170974	validation_1-error:0.169346
# [57]	validation_0-error:0.170974	validation_1-error:0.169346
# [58]	validation_0-error:0.170974	validation_1-error:0.169346
# [59]	validation_0-error:0.171013	validation_1-error:0.169192
# [60]	validation_0-error:0.171	validation_1-error:0.169161
# [61]	validation_0-error:0.171	validation_1-error:0.169161
# [62]	validation_0-error:0.171	validation_1-error:0.169161
# [63]	validation_0-error:0.170974	validation_1-error:0.169161
# [64]	validation_0-error:0.170974	validation_1-error:0.169161
# [65]	validation_0-error:0.170974	validation_1-error:0.169161
# [66]	validation_0-error:0.170974	validation_1-error:0.169161
# [67]	validation_0-error:0.170974	validation_1-error:0.169161
# [68]	validation_0-error:0.171	validation_1-error:0.169284
# [69]	validation_0-error:0.171	validation_1-error:0.169284
# [70]	validation_0-error:0.171	validation_1-error:0.169284
# [71]	validation_0-error:0.171	validation_1-error:0.169284
# [72]	validation_0-error:0.171	validation_1-error:0.169284
# [73]	validation_0-error:0.171092	validation_1-error:0.169253
# [74]	validation_0-error:0.171092	validation_1-error:0.169253
# [75]	validation_0-error:0.171092	validation_1-error:0.169253
# [76]	validation_0-error:0.171092	validation_1-error:0.169253
# [77]	validation_0-error:0.171092	validation_1-error:0.169253
# [78]	validation_0-error:0.171053	validation_1-error:0.169253
# [79]	validation_0-error:0.171066	validation_1-error:0.169223
# [80]	validation_0-error:0.170987	validation_1-error:0.169038
# [81]	validation_0-error:0.171013	validation_1-error:0.169038
# [82]	validation_0-error:0.171013	validation_1-error:0.169008
# [83]	validation_0-error:0.171	validation_1-error:0.169008
# [84]	validation_0-error:0.171	validation_1-error:0.169008
# [85]	validation_0-error:0.171013	validation_1-error:0.169008
# [86]	validation_0-error:0.171013	validation_1-error:0.169008
# [87]	validation_0-error:0.171013	validation_1-error:0.169008
# [88]	validation_0-error:0.171066	validation_1-error:0.169069
# [89]	validation_0-error:0.171066	validation_1-error:0.169069
# [90]	validation_0-error:0.171066	validation_1-error:0.169069
# [91]	validation_0-error:0.171066	validation_1-error:0.169069
# [92]	validation_0-error:0.171066	validation_1-error:0.169069
# [93]	validation_0-error:0.170948	validation_1-error:0.169008
# [94]	validation_0-error:0.170948	validation_1-error:0.168977
# [95]	validation_0-error:0.170948	validation_1-error:0.168977
# [96]	validation_0-error:0.170948	validation_1-error:0.168977
# [97]	validation_0-error:0.170908	validation_1-error:0.168946
# [98]	validation_0-error:0.170908	validation_1-error:0.168946
# [99]	validation_0-error:0.170895	validation_1-error:0.168915
# [100]	validation_0-error:0.170895	validation_1-error:0.168915
# [101]	validation_0-error:0.170895	validation_1-error:0.168915
# [102]	validation_0-error:0.170895	validation_1-error:0.168915
# [103]	validation_0-error:0.170895	validation_1-error:0.168915
# [104]	validation_0-error:0.170895	validation_1-error:0.168915
# [105]	validation_0-error:0.170869	validation_1-error:0.168915
# [106]	validation_0-error:0.170869	validation_1-error:0.168915
# [107]	validation_0-error:0.170869	validation_1-error:0.168915
# [108]	validation_0-error:0.170869	validation_1-error:0.168977
# [109]	validation_0-error:0.170895	validation_1-error:0.169069
# [110]	validation_0-error:0.170895	validation_1-error:0.169069
# [111]	validation_0-error:0.170895	validation_1-error:0.169069
# [112]	validation_0-error:0.170895	validation_1-error:0.169069
# [113]	validation_0-error:0.170895	validation_1-error:0.169069
# [114]	validation_0-error:0.170895	validation_1-error:0.169008
# [115]	validation_0-error:0.170895	validation_1-error:0.169008
# [116]	validation_0-error:0.170882	validation_1-error:0.169008
# [117]	validation_0-error:0.170882	validation_1-error:0.169008
# [118]	validation_0-error:0.170829	validation_1-error:0.1691
# [119]	validation_0-error:0.170816	validation_1-error:0.1691
# [120]	validation_0-error:0.170816	validation_1-error:0.1691
# [121]	validation_0-error:0.170816	validation_1-error:0.1691
# [122]	validation_0-error:0.170816	validation_1-error:0.1691
# [123]	validation_0-error:0.170816	validation_1-error:0.1691
# [124]	validation_0-error:0.170803	validation_1-error:0.1691
# [125]	validation_0-error:0.170803	validation_1-error:0.1691
# [126]	validation_0-error:0.170776	validation_1-error:0.169069
# [127]	validation_0-error:0.170776	validation_1-error:0.169069
# [128]	validation_0-error:0.170803	validation_1-error:0.169008
# [129]	validation_0-error:0.170803	validation_1-error:0.169008
# [130]	validation_0-error:0.170842	validation_1-error:0.169008
# [131]	validation_0-error:0.170842	validation_1-error:0.169008
# [132]	validation_0-error:0.170842	validation_1-error:0.169008
# [133]	validation_0-error:0.170842	validation_1-error:0.169008
# [134]	validation_0-error:0.17079	validation_1-error:0.169008
# [135]	validation_0-error:0.17079	validation_1-error:0.169008
# [136]	validation_0-error:0.17079	validation_1-error:0.169008
# [137]	validation_0-error:0.17079	validation_1-error:0.169008
# [138]	validation_0-error:0.17079	validation_1-error:0.169008
# [139]	validation_0-error:0.17079	validation_1-error:0.169008
# [140]	validation_0-error:0.170737	validation_1-error:0.169008
# [141]	validation_0-error:0.17075	validation_1-error:0.169008
# [142]	validation_0-error:0.17075	validation_1-error:0.169008
# [143]	validation_0-error:0.17075	validation_1-error:0.169008
# [144]	validation_0-error:0.17075	validation_1-error:0.169008
# [145]	validation_0-error:0.17075	validation_1-error:0.169008
# [146]	validation_0-error:0.17075	validation_1-error:0.169008
# [147]	validation_0-error:0.170737	validation_1-error:0.169008
# [148]	validation_0-error:0.17079	validation_1-error:0.169008
# [149]	validation_0-error:0.170711	validation_1-error:0.169008
# [150]	validation_0-error:0.170711	validation_1-error:0.169008
# [151]	validation_0-error:0.170711	validation_1-error:0.169008
# [152]	validation_0-error:0.170711	validation_1-error:0.169008
# [153]	validation_0-error:0.170711	validation_1-error:0.169038
# [154]	validation_0-error:0.170711	validation_1-error:0.169038
# [155]	validation_0-error:0.170711	validation_1-error:0.169038
# [156]	validation_0-error:0.170763	validation_1-error:0.169131
# [157]	validation_0-error:0.170763	validation_1-error:0.1691
# [158]	validation_0-error:0.170763	validation_1-error:0.1691
# [159]	validation_0-error:0.170763	validation_1-error:0.1691
# [160]	validation_0-error:0.170724	validation_1-error:0.169161
# [161]	validation_0-error:0.170724	validation_1-error:0.169161
# [162]	validation_0-error:0.170724	validation_1-error:0.169161
# [163]	validation_0-error:0.170724	validation_1-error:0.169161
# [164]	validation_0-error:0.170724	validation_1-error:0.169161
# [165]	validation_0-error:0.17075	validation_1-error:0.1691
# [166]	validation_0-error:0.17075	validation_1-error:0.1691
# [167]	validation_0-error:0.17075	validation_1-error:0.169069
# [168]	validation_0-error:0.17075	validation_1-error:0.169069
# [169]	validation_0-error:0.17075	validation_1-error:0.169069
# [170]	validation_0-error:0.17075	validation_1-error:0.169069
# [171]	validation_0-error:0.17075	validation_1-error:0.169069
# [172]	validation_0-error:0.17075	validation_1-error:0.169069
# [173]	validation_0-error:0.17075	validation_1-error:0.169069
# [174]	validation_0-error:0.17075	validation_1-error:0.169069
# [175]	validation_0-error:0.17075	validation_1-error:0.169069
# [176]	validation_0-error:0.17075	validation_1-error:0.169069
# [177]	validation_0-error:0.17075	validation_1-error:0.169069
# [178]	validation_0-error:0.170724	validation_1-error:0.169069
# [179]	validation_0-error:0.170711	validation_1-error:0.169038
# [180]	validation_0-error:0.170684	validation_1-error:0.169069
# [181]	validation_0-error:0.170684	validation_1-error:0.169069
# [182]	validation_0-error:0.170658	validation_1-error:0.169008
# [183]	validation_0-error:0.170658	validation_1-error:0.169008
# [184]	validation_0-error:0.170658	validation_1-error:0.169008
# [185]	validation_0-error:0.170658	validation_1-error:0.169008
# [186]	validation_0-error:0.170658	validation_1-error:0.169008
# [187]	validation_0-error:0.170658	validation_1-error:0.168977
# [188]	validation_0-error:0.170658	validation_1-error:0.168977
# [189]	validation_0-error:0.170658	validation_1-error:0.168977
# [190]	validation_0-error:0.170671	validation_1-error:0.168946
# [191]	validation_0-error:0.170671	validation_1-error:0.168946
# [192]	validation_0-error:0.170658	validation_1-error:0.168946
# [193]	validation_0-error:0.170658	validation_1-error:0.168946
# [194]	validation_0-error:0.170658	validation_1-error:0.168946
# [195]	validation_0-error:0.170658	validation_1-error:0.168946
# [196]	validation_0-error:0.170658	validation_1-error:0.168915
# [197]	validation_0-error:0.170658	validation_1-error:0.168915
# [198]	validation_0-error:0.170658	validation_1-error:0.168915
# [199]	validation_0-error:0.170658	validation_1-error:0.168915
# [200]	validation_0-error:0.170631	validation_1-error:0.168915
# [201]	validation_0-error:0.170605	validation_1-error:0.168915
# [202]	validation_0-error:0.170605	validation_1-error:0.168885
# [203]	validation_0-error:0.170605	validation_1-error:0.168885
# [204]	validation_0-error:0.170605	validation_1-error:0.168854
# [205]	validation_0-error:0.170526	validation_1-error:0.168885
# [206]	validation_0-error:0.170526	validation_1-error:0.168885
# [207]	validation_0-error:0.170526	validation_1-error:0.168915
# [208]	validation_0-error:0.170526	validation_1-error:0.168915
# [209]	validation_0-error:0.170526	validation_1-error:0.168915
# [210]	validation_0-error:0.170526	validation_1-error:0.168915
# [211]	validation_0-error:0.170526	validation_1-error:0.168885
# [212]	validation_0-error:0.170526	validation_1-error:0.168885
# [213]	validation_0-error:0.170526	validation_1-error:0.168885
# [214]	validation_0-error:0.170526	validation_1-error:0.168946
# [215]	validation_0-error:0.170526	validation_1-error:0.168946
# [216]	validation_0-error:0.170526	validation_1-error:0.168946
# [217]	validation_0-error:0.170618	validation_1-error:0.168915
# [218]	validation_0-error:0.170618	validation_1-error:0.168915
# [219]	validation_0-error:0.170618	validation_1-error:0.168885
# [220]	validation_0-error:0.170618	validation_1-error:0.168885
# [221]	validation_0-error:0.170526	validation_1-error:0.168915
# [222]	validation_0-error:0.170618	validation_1-error:0.168885
# [223]	validation_0-error:0.170618	validation_1-error:0.168854
# [224]	validation_0-error:0.170618	validation_1-error:0.168885
# [225]	validation_0-error:0.170618	validation_1-error:0.168885
# [226]	validation_0-error:0.170605	validation_1-error:0.168885
# [227]	validation_0-error:0.170631	validation_1-error:0.168854
# [228]	validation_0-error:0.170408	validation_1-error:0.168885
# [229]	validation_0-error:0.170381	validation_1-error:0.168885
# [230]	validation_0-error:0.170381	validation_1-error:0.168885
# [231]	validation_0-error:0.170381	validation_1-error:0.168885
# [232]	validation_0-error:0.170381	validation_1-error:0.168885
# [233]	validation_0-error:0.170355	validation_1-error:0.168854
# [234]	validation_0-error:0.170342	validation_1-error:0.168885
# [235]	validation_0-error:0.170355	validation_1-error:0.168885
# [236]	validation_0-error:0.170355	validation_1-error:0.168885
# [237]	validation_0-error:0.170355	validation_1-error:0.168885
# [238]	validation_0-error:0.170355	validation_1-error:0.168885
# [239]	validation_0-error:0.170355	validation_1-error:0.168885
# [240]	validation_0-error:0.170355	validation_1-error:0.168885
# [241]	validation_0-error:0.170355	validation_1-error:0.168854
# [242]	validation_0-error:0.170329	validation_1-error:0.168915
# [243]	validation_0-error:0.170381	validation_1-error:0.168854
# [244]	validation_0-error:0.170381	validation_1-error:0.168885
# [245]	validation_0-error:0.170381	validation_1-error:0.168885
# [246]	validation_0-error:0.170381	validation_1-error:0.168885
# [247]	validation_0-error:0.170394	validation_1-error:0.168885
# [248]	validation_0-error:0.170394	validation_1-error:0.168885
# [249]	validation_0-error:0.170368	validation_1-error:0.168885
# accuracy: 83.111535
# Text(0.5, 0, 'Número de árboles')

# %%
N = 20 #Para no graficar todos los puntos y saturar el grafico

plt.figure(figsize = (8,6))

ax = sns.scatterplot(X_test[::N].MaxTemp, X_test[::N].Humidity3pm, hue=y_test[::N], palette='Set2')
xlim = ax.get_xlim()
ylim = ax.get_ylim()
xx, yy = np.meshgrid(np.linspace(*xlim, num=200),
                      np.linspace(*ylim, num=200))
Z = ada_clf.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
contours = ax.contourf(xx, yy, Z, alpha=0.3, cmap = 'Set2')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
